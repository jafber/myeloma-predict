# %% [markdown]
# # Data Cleaning Pipeline
#
# Reads `data/myeloma_data.csv`, selects relevant columns, renames them to `lower_snake_case`, maps ancestry, converts time from months to years, standardizes continuous features, and exports the result to `cleaned_data/`.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from pathlib import Path

DATA_PATH = 'data/myeloma_data.csv'
OUTPUT_DIR = Path('cleaned_data')
OUTPUT_DIR.mkdir(exist_ok=True)

# %% [markdown]
# ## Load raw data

# %%
df_raw = pd.read_csv(DATA_PATH, index_col='ID')
print(f'Rows: {len(df_raw)}, Columns: {list(df_raw.columns)}')
df_raw.head()
# Out:
# Rows: 2000, Columns: ['Ancestry', 'PGS_Score', 'Age', 'M_Spike', 'sFLC_Ratio', 'Creatinine', 'LP', 'Time_Months', 'Status', 'BMPC_Final', 'Hgb_Final', 'PGS_Bin', 'Clinical_Risk']
#     Ancestry  PGS_Score        Age   M_Spike  sFLC_Ratio  Creatinine  \
# ID
# 1   European  -0.006056  69.111929  3.282018    3.010026    0.522791
# 2   European   0.996723  74.327334  3.468359    3.372553    1.028067
# 3   European   0.723133  67.378696  0.588324    2.718493    0.775595
# 4   European   0.821519  72.769428  1.222824    6.164781    0.943936
# 5   European  -0.806482  64.201009  2.228350    0.438690    0.978404
#
#           LP  Time_Months  Status  BMPC_Final  Hgb_Final     PGS_Bin  \
# ID
# 1   2.172474        16.02       1    25.01001  14.598307  Medium PGS
# 2   2.034360         0.80       1         NaN  15.478983  Medium PGS
# 3   0.134618       107.38       0     0.15043  12.717573  Medium PGS
# 4   2.541208        51.56       1         NaN        NaN  Medium PGS
# 5   0.603776        45.18       0         NaN  12.620185  Medium PGS
#
#         Clinical_Risk
# ID
# 1   Int Clinical Risk
# 2   Int Clinical Risk
# 3   Low Clinical Risk
# 4   Low Clinical Risk
# 5   Int Clinical Risk

# %% [markdown]
# ## Select columns and convert time

# %%
feature_cols = [
    'Ancestry',
    'Age',
    'M_Spike',
    'sFLC_Ratio',
    'Creatinine',
    'PGS_Score',
    'PGS_Bin',
    'BMPC_Final',
    'Hgb_Final'
]
duration_col = 'Time_Months'
event_col = 'Status'

df = df_raw[feature_cols + [duration_col, event_col]].copy()

# Convert time from months to years
df['Time_Years'] = df['Time_Months'] / 12
df = df.drop(columns=['Time_Months'])

# %% [markdown]
# ## Rename to lower_snake_case

# %%
rename_map = {
    'Ancestry':   'ancestry',
    'Age':        'age',
    'M_Spike':    'm_spike',
    'sFLC_Ratio': 'sflc_ratio',
    'Creatinine': 'creatinine',
    'PGS_Score':  'pgs_score',
    'PGS_Bin':    'pgs_bin',
    'Time_Years': 'time_years',
    'Status':     'status',
    'BMPC_Final': 'bmpc',
    'Hgb_Final':  'hgb',
}
df = df.rename(columns=rename_map)
df.head()
# Out:
#     ancestry        age   m_spike  sflc_ratio  creatinine  pgs_score  \
# ID
# 1   European  69.111929  3.282018    3.010026    0.522791  -0.006056
# 2   European  74.327334  3.468359    3.372553    1.028067   0.996723
# 3   European  67.378696  0.588324    2.718493    0.775595   0.723133
# 4   European  72.769428  1.222824    6.164781    0.943936   0.821519
# 5   European  64.201009  2.228350    0.438690    0.978404  -0.806482
#
#        pgs_bin      bmpc        hgb  status  time_years
# ID
# 1   Medium PGS  25.01001  14.598307       1    1.335000
# 2   Medium PGS       NaN  15.478983       1    0.066667
# 3   Medium PGS   0.15043  12.717573       0    8.948333
# 4   Medium PGS       NaN        NaN       1    4.296667
# 5   Medium PGS       NaN  12.620185       0    3.765000

# %% [markdown]
# ## Map ancestry (European → 1, African American → 0)

# %%
df['ancestry'] = df['ancestry'].map({'European': 1, 'African American': 0})
print('Ancestry value counts:')
print(df['ancestry'].value_counts())
# Out:
# Ancestry value counts:
# ancestry
# 1    1593
# 0     407
# Name: count, dtype: int64

# %% [markdown]
# ## Encode PGS_Bin (ordinal: Low=0, Medium=1, High=2)

# %%
pgs_bin_map = {'Low PGS': 0, 'Medium PGS': 1, 'High PGS': 2}
df['pgs_bin'] = df['pgs_bin'].map(pgs_bin_map)
print('PGS bin value counts:')
print(df['pgs_bin'].value_counts().sort_index())
# Out:
# PGS bin value counts:
# pgs_bin
# 0     336
# 1    1373
# 2     291
# Name: count, dtype: int64

# %% [markdown]
# # Impute missing values using KNN imputation

# %%
from sklearn.impute import KNNImputer

before_missing = df[['hgb', 'bmpc']].isnull().sum()
print('Missing before imputation:')
print(before_missing)

cols_to_use = rename_map.values()  # Use all features for imputation

imputer = KNNImputer(n_neighbors=5, weights='distance')
imputed = imputer.fit_transform(df[cols_to_use])

imputed_df = pd.DataFrame(imputed, index=df.index, columns=cols_to_use)

# Assign imputed values back for hgb only
df['hgb'] = imputed_df['hgb']

after_missing = df[['hgb', 'bmpc']].isnull().sum()
print('Missing after imputation:')
print(after_missing)

print('Imputed value summaries:')
print(df[['hgb', 'bmpc']].describe().round(4))
# Out:
# Missing before imputation:
# hgb     200
# bmpc    700
# dtype: int64
# Missing after imputation:
# hgb       0
# bmpc    700
# dtype: int64
# Imputed value summaries:
#              hgb       bmpc
# count  2000.0000  1300.0000
# mean     13.0227     8.8125
# std       1.4319     7.7042
# min       8.7412     0.0070
# 25%      12.0992     2.7301
# 50%      13.0389     6.4442
# 75%      13.9323    13.0195
# max      17.7694    39.0121

# %% [markdown]
# # Create boolean indicator to show if bmpc was measured

# %%
df['was_bmpc_measured'] = df['bmpc'].notnull().astype(int)
print('Was BMPC measured value counts:')
print(df['was_bmpc_measured'].value_counts())
# Out:
# Was BMPC measured value counts:
# was_bmpc_measured
# 1    1300
# 0     700
# Name: count, dtype: int64

# %% [markdown]
# ## Standardize continuous feature columns
#
# Ancestry is binary (0/1) and is left as-is. All other feature columns are z-score standardized.

# %%
continuous_features = ['age', 'm_spike', 'sflc_ratio', 'creatinine', 'pgs_score']
# pgs_bin is ordinal (0/1/2) and is intentionally left on its original scale

scaler = StandardScaler()
df[continuous_features] = scaler.fit_transform(df[continuous_features])

print('Feature statistics after standardization:')
df[continuous_features].describe().round(4)
# Out:
# Feature statistics after standardization:
#              age    m_spike  sflc_ratio  creatinine  pgs_score
# count  2000.0000  2000.0000   2000.0000   2000.0000  2000.0000
# mean      0.0000    -0.0000      0.0000      0.0000     0.0000
# std       1.0003     1.0003      1.0003      1.0003     1.0003
# min      -2.7340    -1.3972     -0.6103     -2.2628    -3.0406
# 25%      -0.6713    -0.7451     -0.4775     -0.7038    -0.6924
# 50%      -0.0010    -0.2383     -0.3108     -0.1120     0.0158
# 75%       0.6635     0.4854      0.0644      0.6110     0.6760
# max       3.7924     6.0289     17.4869      4.2248     3.8405

# %% [markdown]
# ## Inspect cleaned dataset

# %%
print(f'Shape: {df.shape}')
print(f'Missing values:\n{df.isnull().sum()}')
df.head()
# Out:
# Shape: (2000, 12)
# Missing values:
# ancestry               0
# age                    0
# m_spike                0
# sflc_ratio             0
# creatinine             0
# pgs_score              0
# pgs_bin                0
# bmpc                 700
# hgb                    0
# status                 0
# time_years             0
# was_bmpc_measured      0
# dtype: int64
#     ancestry       age   m_spike  sflc_ratio  creatinine  pgs_score  pgs_bin  \
# ID
# 1          1  0.137747  2.422286   -0.287442   -1.718453   0.012128        1
# 2          1  0.652230  2.640049   -0.247821    0.424321   1.002874        1
# 3          1 -0.033230 -0.725654   -0.319304   -0.646363   0.732567        1
# 4          1  0.498547  0.015844    0.057345    0.067536   0.829773        1
# 5          1 -0.346698  1.190935   -0.568467    0.213709  -0.778696        1
#
#         bmpc        hgb  status  time_years  was_bmpc_measured
# ID
# 1   25.01001  14.598307       1    1.335000                  1
# 2        NaN  15.478983       1    0.066667                  0
# 3    0.15043  12.717573       0    8.948333                  1
# 4        NaN  12.269072       1    4.296667                  0
# 5        NaN  12.620185       0    3.765000                  0

# %% [markdown]
# ## Export to cleaned_data/

# %%
datasets = {
    'all_features': [
        'age', 'm_spike', 'sflc_ratio', 'creatinine', 'time_years', 'status', 
        'pgs_score', 'pgs_bin', 'bmpc', 'hgb', 'ancestry', 'was_bmpc_measured'
    ],
    'mm_pgs_bin': [
        'age', 'm_spike', 'sflc_ratio', 'creatinine', 'time_years', 'status',  'was_bmpc_measured', 'hgb', 'pgs_bin'
    ],
    'mm_nopgs': [
        'age', 'm_spike', 'sflc_ratio', 'creatinine', 'time_years', 'status', 'was_bmpc_measured', 'hgb'
    ],
}

for name, features in datasets.items():
    output_path = OUTPUT_DIR / f'{name}.csv'
    df[features].to_csv(output_path)
    print(f'Saved {len(df)} rows to {output_path}')
# Out:
# Saved 2000 rows to cleaned_data/all_features.csv
# Saved 2000 rows to cleaned_data/mm_pgs_bin.csv
# Saved 2000 rows to cleaned_data/mm_nopgs.csv

# %%
import json

feature_stats = {
    feat: {"mean": scaler.mean_[i], "std": scaler.scale_[i]}
    for i, feat in enumerate(continuous_features)
}

stats_path = OUTPUT_DIR / 'feature_stats.json'
with open(stats_path, 'w') as f:
    json.dump(feature_stats, f, indent=2)

print(f'Saved feature stats to {stats_path}:')
print(json.dumps(feature_stats, indent=2))
# Out:
# Saved feature stats to cleaned_data/feature_stats.json:
# {
#   "age": {
#     "mean": 67.71555658256379,
#     "std": 10.137193389180013
#   },
#   "m_spike": {
#     "mean": 1.2092668187728803,
#     "std": 0.8557006790358146
#   },
#   "sflc_ratio": {
#     "mean": 5.640079859242227,
#     "std": 9.149846066886683
#   },
#   "creatinine": {
#     "mean": 0.9280104678412231,
#     "std": 0.23580461873718578
#   },
#   "pgs_score": {
#     "mean": -0.018330529093263884,
#     "std": 1.0121437141316436
#   }
# }
